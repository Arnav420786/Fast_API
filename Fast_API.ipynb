# %%
import nest_asyncio 
# !pip install fastapi uvicorn nest_asyncio
import pandas as pd

# %%
df = pd.read_csv('Crypto_live_data')

# %%
df
# Out:
#                      CoinName  Buy      Price   1hr  24hr    7d  24hrVoume  \
# 0                Bitcoin\nBTC  Buy   $110,059  0.1%  1.3%  1.1%        NaN
# 1               Ethereum\nETH  Buy  $4,257.96  0.4%  1.7%  2.2%        NaN
# 2                Tether\nUSDT  Buy      $1.00  0.0%  0.0%  0.0%        NaN
# 3                    XRP\nXRP  Buy      $2.80  0.2%  2.2%  0.4%        NaN
# 4                    BNB\nBNB  Buy    $857.44  0.3%  0.7%  0.1%        NaN
# ..                        ...  ...        ...   ...   ...   ...        ...
# 95  Renzo Restaked ETH\nEZETH  NaN  $4,499.77  0.5%  1.5%  2.2%        NaN
# 96                 Four\nFORM  NaN      $3.69  0.2%  0.3%  0.8%        NaN
# 97           XDC Network\nXDC  NaN     $0.079  0.3%  2.2%  1.4%        NaN
# 98          Tether Gold\nXAUT  NaN  $3,605.81  0.1%  0.2%  4.6%        NaN
# 99                 NEXO\nNEXO  NaN      $1.27  0.3%  0.6%  2.0%        NaN
#
#           marketCap
# 0   $23,517,173,551
# 1   $15,470,484,830
# ...

# %%
df.drop(columns=['24hrVoume'],inplace=True)

# %%
#df.drop(columns=['C1','D1','E1'],inplace=True)

# %%
#df.drop(columns=['last 7 days'],inplace= True)

# %%
df
# Out:
#                      CoinName  Buy      Price   1hr  24hr    7d  \
# 0                Bitcoin\nBTC  Buy   $110,059  0.1%  1.3%  1.1%
# 1               Ethereum\nETH  Buy  $4,257.96  0.4%  1.7%  2.2%
# 2                Tether\nUSDT  Buy      $1.00  0.0%  0.0%  0.0%
# 3                    XRP\nXRP  Buy      $2.80  0.2%  2.2%  0.4%
# 4                    BNB\nBNB  Buy    $857.44  0.3%  0.7%  0.1%
# ..                        ...  ...        ...   ...   ...   ...
# 95  Renzo Restaked ETH\nEZETH  NaN  $4,499.77  0.5%  1.5%  2.2%
# 96                 Four\nFORM  NaN      $3.69  0.2%  0.3%  0.8%
# 97           XDC Network\nXDC  NaN     $0.079  0.3%  2.2%  1.4%
# 98          Tether Gold\nXAUT  NaN  $3,605.81  0.1%  0.2%  4.6%
# 99                 NEXO\nNEXO  NaN      $1.27  0.3%  0.6%  2.0%
#
#           marketCap
# 0   $23,517,173,551
# 1   $15,470,484,830
# 2   $48,267,332,457
# 3    $2,411,275,471
# 4      $957,140,530
# ..              ...
# 95       $5,018,311
# 96      $13,132,188
# ...

# %%
df.columns=['Coin','Buy/Sell','Price','1hr','24hr','7d','Market Cap']

# %%
df
# Out:
#                          Coin Buy/Sell      Price   1hr  24hr    7d  \
# 0                Bitcoin\nBTC      Buy   $110,059  0.1%  1.3%  1.1%
# 1               Ethereum\nETH      Buy  $4,257.96  0.4%  1.7%  2.2%
# 2                Tether\nUSDT      Buy      $1.00  0.0%  0.0%  0.0%
# 3                    XRP\nXRP      Buy      $2.80  0.2%  2.2%  0.4%
# 4                    BNB\nBNB      Buy    $857.44  0.3%  0.7%  0.1%
# ..                        ...      ...        ...   ...   ...   ...
# 95  Renzo Restaked ETH\nEZETH      NaN  $4,499.77  0.5%  1.5%  2.2%
# 96                 Four\nFORM      NaN      $3.69  0.2%  0.3%  0.8%
# 97           XDC Network\nXDC      NaN     $0.079  0.3%  2.2%  1.4%
# 98          Tether Gold\nXAUT      NaN  $3,605.81  0.1%  0.2%  4.6%
# 99                 NEXO\nNEXO      NaN      $1.27  0.3%  0.6%  2.0%
#
#          Market Cap
# 0   $23,517,173,551
# 1   $15,470,484,830
# 2   $48,267,332,457
# 3    $2,411,275,471
# 4      $957,140,530
# ..              ...
# ...

# %%
df.fillna(" ")
# Out:
#                          Coin Buy/Sell      Price   1hr  24hr    7d  \
# 0                Bitcoin\nBTC      Buy   $110,059  0.1%  1.3%  1.1%
# 1               Ethereum\nETH      Buy  $4,257.96  0.4%  1.7%  2.2%
# 2                Tether\nUSDT      Buy      $1.00  0.0%  0.0%  0.0%
# 3                    XRP\nXRP      Buy      $2.80  0.2%  2.2%  0.4%
# 4                    BNB\nBNB      Buy    $857.44  0.3%  0.7%  0.1%
# ..                        ...      ...        ...   ...   ...   ...
# 95  Renzo Restaked ETH\nEZETH           $4,499.77  0.5%  1.5%  2.2%
# 96                 Four\nFORM               $3.69  0.2%  0.3%  0.8%
# 97           XDC Network\nXDC              $0.079  0.3%  2.2%  1.4%
# 98          Tether Gold\nXAUT           $3,605.81  0.1%  0.2%  4.6%
# 99                 NEXO\nNEXO               $1.27  0.3%  0.6%  2.0%
#
#          Market Cap
# 0   $23,517,173,551
# 1   $15,470,484,830
# 2   $48,267,332,457
# 3    $2,411,275,471
# 4      $957,140,530
# ..              ...
# ...

# %%
df = df.where(pd.notnull(df), '')

# %%
df
# Out:
#                          Coin Buy/Sell      Price   1hr  24hr    7d  \
# 0                Bitcoin\nBTC      Buy   $110,059  0.1%  1.3%  1.1%
# 1               Ethereum\nETH      Buy  $4,257.96  0.4%  1.7%  2.2%
# 2                Tether\nUSDT      Buy      $1.00  0.0%  0.0%  0.0%
# 3                    XRP\nXRP      Buy      $2.80  0.2%  2.2%  0.4%
# 4                    BNB\nBNB      Buy    $857.44  0.3%  0.7%  0.1%
# ..                        ...      ...        ...   ...   ...   ...
# 95  Renzo Restaked ETH\nEZETH           $4,499.77  0.5%  1.5%  2.2%
# 96                 Four\nFORM               $3.69  0.2%  0.3%  0.8%
# 97           XDC Network\nXDC              $0.079  0.3%  2.2%  1.4%
# 98          Tether Gold\nXAUT           $3,605.81  0.1%  0.2%  4.6%
# 99                 NEXO\nNEXO               $1.27  0.3%  0.6%  2.0%
#
#          Market Cap
# 0   $23,517,173,551
# 1   $15,470,484,830
# 2   $48,267,332,457
# 3    $2,411,275,471
# 4      $957,140,530
# ..              ...
# ...

# %%
from fastapi import FastAPI
import uvicorn

# %%
'''@app.get("/")
def home():
    return {"message": "Welcome to Crypto API"}'''

# %%
'''nest_asyncio.apply()

app = FastAPI()

@app.get("/cryptos")
def get_cryptos():
    return df.to_dict(orient="records")
uvicorn.run(app, host="127.0.0.1", port=8000)'''
# Out:
# 'nest_asyncio.apply()\n\napp = FastAPI()\n\n@app.get("/cryptos")\ndef get_cryptos():\n    return df.to_dict(orient="records")\nuvicorn.run(app, host="127.0.0.1", port=8000)'

# %%
nest_asyncio.apply()

app = FastAPI()

@app.get("/arnav")
def home():
    return df.to_dict(orient="records") 

uvicorn.run(app, host="127.0.0.1", port=8000)
# Out:
# INFO:     Started server process [7288]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     127.0.0.1:55976 - "GET /arnav HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [7288]
